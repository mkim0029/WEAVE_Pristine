# %% [markdown]
# # Explore Raw Spectra and Metadata
#
# This notebook visualizes raw spectral data from the HDF5 file and analyzes the distribution of stellar labels from the metadata CSV.

# %%
import h5py
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define paths
data_dir = "../previous_data"
hdf5_path = os.path.join(data_dir, "raw_spectra_10k.h5")
metadata_path = os.path.join(data_dir, "raw_spectra_10k_metadata.csv")

print(f"HDF5 Path: {hdf5_path}")
print(f"Metadata Path: {metadata_path}")
# Out:
# HDF5 Path: ../previous_data/raw_spectra_10k.h5
# Metadata Path: ../previous_data/raw_spectra_10k_metadata.csv

# %% [markdown]
# ## Load Metadata
# First, we load the metadata to identify available spectra and their keys.

# %%
# Load metadata CSV
df = pd.read_csv(metadata_path)
print(f"Loaded metadata with {len(df)} rows.")
df.head()
# Out:
# Loaded metadata with 10000 rows.
#     star_name  Teff  logg   FeH  vmic  geometry    Ca    Mg    Si    Ti  ...  \
# 0  chunk__000  5294  2.25 -3.58  1.61       1.0  0.81 -0.47 -0.31 -1.76  ...
# 1  chunk__001  7348  1.80 -3.54  2.11       1.0  0.73  0.43 -1.95 -0.08  ...
# 2  chunk__002  7131  2.53 -1.23  1.74       1.0 -0.70 -1.31 -0.87  1.07  ...
# 3  chunk__003  5010  2.41 -1.97  2.17       1.0  0.10  0.96 -0.05  1.04  ...
# 4  chunk__004  5476  2.17 -3.33  2.26       1.0 -0.16 -0.69  0.07  1.08  ...
#
#       C     N    Li    Nd     V    Cu    Sc     Y             hdf5_key  \
# 0 -0.18 -1.89  0.29 -1.78 -0.23 -1.27  0.85  0.91  chunk_90_chunk__000
# 1  0.05  1.02 -1.15  0.30  0.66 -0.05  0.15 -1.85  chunk_90_chunk__001
# 2 -0.54  1.58 -1.81  0.82 -0.84 -0.77 -0.83 -0.09  chunk_90_chunk__002
# 3  0.50  0.66  0.92  1.07 -1.59  1.06 -0.67 -0.96  chunk_90_chunk__003
# 4 -0.12 -1.34  0.01 -0.84  0.82 -0.65  0.96 -0.87  chunk_90_chunk__004
#
#    original_chunk
# 0        chunk_90
# ...

# %% [markdown]
# ## Visualize Spectrum
# We select a spectrum using the `hdf5_key` from the metadata and plot its wavelength vs flux.

# %%
# Select a spectrum index
idx = 45
row = df.iloc[idx]
key = row['hdf5_key']
print(f"Visualizing spectrum for index {idx}, Key: {key}")

with h5py.File(hdf5_path, 'r') as hf:
    # Access the dataset
    # Structure is raw_spectra/{key}
    if "raw_spectra" in hf:
        data = hf["raw_spectra"][key][:]
        
        # Assuming data is [N, 2] (wavelength, flux)
        wavelength = data[:, 0]
        flux = data[:, 1]
        
        plt.figure(figsize=(12, 6))
        plt.plot(wavelength, flux, lw=0.5)
        plt.xlabel("Wavelength (Å)")
        plt.ylabel("Flux")
        plt.title(f"Raw Spectrum: {key}")
        plt.grid(True, alpha=0.3)
        plt.ylim(0, 3e15)
        plt.show()
    else:
        print("Group 'raw_spectra' not found in HDF5.")
# Out:
# Visualizing spectrum for index 45, Key: chunk_90_chunk__045

# %%
import numpy as np
np.max(flux)
# Out:
# np.float64(1.435e+18)

# %% [markdown]
# ## Metadata Distributions
# We analyze the distributions of key stellar labels: Teff, logg, FeH, vmic, and geometry.

# %%
labels = ['Teff', 'logg', 'FeH', 'vmic', 'geometry']

plt.figure(figsize=(15, 10))

for i, label in enumerate(labels):
    if label in df.columns:
        plt.subplot(2, 3, i+1)
        plt.hist(df[label].dropna(), bins=30, edgecolor='k', alpha=0.7)
        plt.xlabel(label)
        plt.ylabel("Count")
        plt.title(f"Distribution of {label}")
        plt.grid(True, alpha=0.3)
    else:
        print(f"Label {label} not found in metadata.")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2, 3, 1)
plt.plot(df['Teff'], df['logg'], 'o', alpha=0.3)
plt.xlabel('Teff')
plt.ylabel('log g')
plt.title('Raw samples in Teff-logg space')
plt.grid(True, alpha=0.2)
plt.gca().invert_yaxis() # Invert the y-axis

plt.subplot(2, 3, 2)
plt.plot(df['Teff'], df['FeH'], 'o', alpha=0.3)
plt.xlabel('Teff')
plt.ylabel('[Fe/H]')
plt.title('Raw samples in Teff-[Fe/H] space')
plt.grid(True, alpha=0.2)

plt.subplot(2, 3, 3)
plt.plot(df['logg'], df['FeH'], 'o', alpha=0.3)
plt.xlabel('log g')
plt.ylabel('[Fe/H]')
plt.title('Raw samples in log g-[Fe/H] space')
plt.grid(True, alpha=0.2)

plt.tight_layout()
plt.show()

# %%
# Matplotlib 3D scatter of Teff, logg, FeH
# prepare data (assumes `df` is your metadata DataFrame)
df_sub = df[['Teff', 'logg', 'FeH']].dropna()
x = df_sub['Teff'].values
y = df_sub['logg'].values
z = df_sub['FeH'].values

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(x, y, z, c=z, cmap='viridis', s=12, alpha=0.8, edgecolors='none')

ax.set_xlabel('Teff')
ax.set_ylabel('log g')
ax.set_zlabel('[Fe/H]')
ax.invert_yaxis()  # common for Teff-logg plots (higher logg downwards)

cbar = fig.colorbar(p, pad=0.1)
cbar.set_label('[Fe/H]')

plt.title('LHS samples in Teff - log g - [Fe/H] space')
plt.tight_layout()
plt.show()

# %%
# Plotly interactive 3D scatter of Teff, logg, FeH
import plotly.express as px

df_sub = df[['Teff', 'logg', 'FeH']].dropna()

fig = px.scatter_3d(
    df_sub,
    x='Teff',
    y='logg',
    z='FeH',
    color='Teff',
    color_continuous_scale='Viridis',
    opacity=0.8,
    size_max=6
)

# invert y-axis (logg) so higher logg appears downward
fig.update_layout(
    scene=dict(
        yaxis=dict(autorange='reversed'),
        xaxis_title='Teff',
        yaxis_title='log g',
        zaxis_title='[Fe/H]'
    ),
    title='LHS samples in Teff - log g - [Fe/H] space'
)

fig.show()

# %%
abunds = ['Al', 'Ba', 'C', 'Ca', 'Co', 'Cr', 'Cu', 'Eu', 'Li', 'Mg', 'Mn', 'N', 'Na', 'Nd',
 'Ni', 'O', 'Sc', 'Si', 'Sr', 'Ti', 'V', 'Y', 'Zn']

plt.figure(figsize=(15, 15))

for i, label in enumerate(abunds):
    if label in df.columns:
        plt.subplot(6, 4, i+1)
        plt.hist(df[label].dropna(), bins=30, edgecolor='k', alpha=0.7)
        plt.xlabel('['+label+'/Fe]')
        plt.ylabel("Count")
        plt.title(f"Distribution of {label}")
        plt.grid(True, alpha=0.3)
    else:
        print(f"Label {label} not found in metadata.")

plt.tight_layout()
plt.show()
